# %% [markdown]
# ### Import Dependencies

# %%
from langsmith import Client

# %% [markdown]
# ### Attach Feedback to a specific trace_id in Langsmith

# %% [markdown]
# d1ff45a8-debb-4dda-9d4c-751db02e92e3

# %%
client = Client()

# %%
client.create_feedback(
    run_id="d1ff45a8-debb-4dda-9d4c-751db02e92e3",
    key="feedback",
    score=0,
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('5cc9e81d-882b-45e6-8f02-e1f7ac436cc3'), created_at=datetime.datetime(2025, 10, 30, 10, 34, 52, 937780, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2025, 10, 30, 10, 34, 52, 937784, tzinfo=datetime.timezone.utc), run_id=UUID('d1ff45a8-debb-4dda-9d4c-751db02e92e3'), trace_id=None, key='feedback', score=0, value=None, comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)

# %%
client.create_feedback(
    run_id="d1ff45a8-debb-4dda-9d4c-751db02e92e3",
    key="feedback_1",
    score=1,
    feedback_source_type="api"
)

# %%
client.create_feedback(
    run_id="d1ff45a8-debb-4dda-9d4c-751db02e92e3",
    key="comment",
    value="This is a long form feedback you should use to improve the system!",
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('519348d2-3ddd-41b6-99eb-824838f6070f'), created_at=datetime.datetime(2025, 10, 30, 10, 35, 0, 404894, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2025, 10, 30, 10, 35, 0, 404897, tzinfo=datetime.timezone.utc), run_id=UUID('d1ff45a8-debb-4dda-9d4c-751db02e92e3'), trace_id=None, key='comment', score=None, value='This is a long form feedback you should use to improve the system!', comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)
